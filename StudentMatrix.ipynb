# %%
import numpy as np

# %%
Student_data = np.array([
    [85,90,78],
    [92,88,95],
    [75,80,70],
    [98,96,94]
])

# %%
print(Student_data)
# Out:
# [[85 90 78]
#  [92 88 95]
#  [75 80 70]
#  [98 96 94]]

# %%
print(Student_data.shape)
# Out:
# (4, 3)

# %%
Multiply = np.array([
    [1],
    [1],
    [1]
])

# %%
print(Multiply)
# Out:
# [[1], [1], [1]]

# %%
print(Multiply.shape)
# Out:
# (3, 1)

# %%
Total_mark = Student_data @ Multiply

# %%
print(Total_mark)
# Out:
# [[253]
#  [275]
#  [225]
#  [288]]
